# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Category" : ["A" , "B" , "A" , "B" , "A" , "B"],
    "Store" : ["S1" , "S2" , "S2" , "S1" , "S1" , "S1"],
    "Sales" : [100 , 200 , 340 , 250 , 300 , 700],
    "Quantity" : [10 , 34 , 17 , 23 , 89 , 37]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity
# 0        A    S1    100        10
# 1        B    S2    200        34
# 2        A    S2    340        17
# 3        B    S1    250        23
# 4        A    S1    300        89
# 5        B    S1    700        37

# %%
df.groupby("Store")

# %%
cat = df.groupby("Category")
cat
for i , v in cat:
    print(i)
    print(v)
# Out:
# A
#   Category Store  Sales  Quantity
# 0        A    S1    100        10
# 2        A    S2    340        17
# 4        A    S1    300        89
# B
#   Category Store  Sales  Quantity
# 1        B    S2    200        34
# 3        B    S1    250        23
# 5        B    S1    700        37

# %%
cat = df.groupby("Category")["Sales"].sum()
cat
# Out:
# Category
# A     740
# B    1150
# Name: Sales, dtype: int64

# %% [markdown]
# AGGREGATION

# %%
df["Sales"].mean()
# Out:
# np.float64(315.0)

# %%
df["Sales"].agg(["mean" , "min" , "max"])
# Out:
# mean    315.0
# min     100.0
# max     700.0
# Name: Sales, dtype: float64
